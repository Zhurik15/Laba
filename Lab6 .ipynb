# %% [markdown]
# # Лабораторная работа 6.
# # Сетевые алгоритмы. Динамические алгоритмы поиска путей.

# %% [markdown]
# ## Выполнил студент группы Журавлёв С.А. БСТ2003
# ***

# %% [markdown]
# ### Задание
#
# 1.  Реализовать алгоритм поиска кратчайшего расстояния между двумя вершинами ориентированного взвешенного графа в соответствии с вариантом.
#
# 2.  Предусмотреть задание графа в виде матрицы смежности/инцидентности, читаемой из файла, либо графически с помощью пользовательского интерфейса.
#
# 3.  Разработать графический интерфейс пользователя с визуализацией графа и отображением кратчайшего расстояния между задаваемыми пользователем вершинами.
#
# 4. По результатам работы проанализировать временную сложность работы заданного алгоритма в зависимости от числа узлов и ребер графа.
# Данные представить в виде таблицы.

# %% [markdown]
# ### Варианты заданий:
#
# Вариант | Задание
# :-------- |:-----
# 1, 7, 13, 19, 25 | Алгоритм Флойда-Уоршелла
# 2, 8, 14, 20, 26 | Алгоритм Дейкстры
# 3, 9,15,21,27 | Алгоритм Беллмана-Форда
# 4, 10, 16, 22, 28 | Алгоритм Джонсона
# 5, 11, 17, 23, 29| Алгоритм Левита
# 6, 12, 18, 24, 30 | Алгоритм Йена

# %% [markdown]
# ### Выполнение:

# %%
# !pip install networkx algorithmx matplotlib

# %% [markdown]
# Requirement already satisfied: networkx in c:\users\klim\anaconda3\lib\site-packages (2.6.3)
# Requirement already satisfied: algorithmx in c:\users\klim\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\klimn\anaconda3\lib\site-packages (3.4.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\klim\anaconda3\lib\site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\klim\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\klim\anaconda3\lib\site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\klim\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\klim\anaconda3\lib\site-packages (from matplotlib) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\klimn\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: six in c:\users\klim\anaconda3\lib\site-packages (from cycler>=0.10->matplotlib) (1.16.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import time as t
import floyd_warshall as fw
import convert_adjacency_matrix as cam

start_time = t.time()

with open('inputs.txt', 'r') as inputs:
    global graph
    graph = []

    for line in inputs:
        graph.append(line[:-1].split(', '))

G = nx.DiGraph()
G.add_weighted_edges_from(cam.convert_adjacency_matrix(graph))

pos = nx.planar_layout(G)
nx.draw(G, with_labels='True', pos=pos)
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, 'weight'))


path = fw.fw(graph, 2, 3)
print(path)
path = [(path[i], path[i+1]) for i in range(len(path)-1)]

nx.draw_networkx_edges(G, pos=pos, edgelist=path, edge_color='red')
nx.draw_networkx_edge_labels(G, pos, edge_labels=nx.get_edge_attributes(G, 'weight'))
print(t.time() - start_time)

plt.show()

# %% [markdown]
# [2, 1, 3]
# 0.5146968364715576

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### Вывод
